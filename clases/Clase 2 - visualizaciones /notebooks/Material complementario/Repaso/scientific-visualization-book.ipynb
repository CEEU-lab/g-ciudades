# %%
# clonamos el repo del libro
# !git clone https://github.com/rougier/scientific-visualization-book.git
# Out:
# Cloning into 'scientific-visualization-book'...
# remote: Enumerating objects: 1151, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 1151 (delta 5), reused 7 (delta 3), pack-reused 1139
# Receiving objects: 100% (1151/1151), 297.77 MiB | 32.45 MiB/s, done.
# Resolving deltas: 100% (359/359), done.
# Checking out files: 100% (563/563), done.

# %%
# grabamos la ruta del directorio
import sys
sys.path.append('/content/scientific-visualization-book')

# %% [markdown]
# Nos deplazamos al directorio con código ...

# %%
cd scientific-visualization-book/code
# Out:
# /content/scientific-visualization-book/code

# %% [markdown]
# Listamos los elementos del directorio ...

# %%
# !ls
# Out:
# anatomy    coordinates	 layout        rules		   typography
# animation  data		 optimization  scales-projections  unsorted
# beyond	   defaults	 ornaments     showcases
# colors	   introduction  reference     threed

# %% [markdown]
# Probamos con el primero ...

# %%
cd anatomy
# Out:
# /content/scientific-visualization-book/code/anatomy

# %%
# !ls
# Out:
# anatomy.py	   imgcat.py	  raster-vector.py  zorder.py
# bold-ticklabel.py  inch-cm.py	  ruler.py
# figure-dpi.py	   pixel-font.py  zorder-plots.py

# %%
import anatomy

# %%
# asi podemos ver qué hace el código y replicarlo en el notebook
# !cat anatomy.py
# Out:
# # ----------------------------------------------------------------------------
# # Title:   Scientific Visualisation - Python & Matplotlib
# # Author:  Nicolas P. Rougier
# # License: BSD
# # ----------------------------------------------------------------------------
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
#
# np.random.seed(123)
#
# X = np.linspace(0.5, 3.5, 100)
# Y1 = 3 + np.cos(X)
# Y2 = 1 + np.cos(1 + X / 0.75) / 2
# Y3 = np.random.uniform(Y1, Y2, len(X))
#
# fig = plt.figure(figsize=(8, 8))
# ax = fig.add_subplot(1, 1, 1, aspect=1)
#
#
# def minor_tick(x, pos):
#     if not x % 1.0:
#         return ""
#     return "%.2f" % x
#
#
# ax.xaxis.set_major_locator(MultipleLocator(1.000))
# ax.xaxis.set_minor_locator(AutoMinorLocator(4))
# ax.yaxis.set_major_locator(MultipleLocator(1.000))
# ax.yaxis.set_minor_locator(AutoMinorLocator(4))
# ...
